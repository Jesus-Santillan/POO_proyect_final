# %% [markdown]
# #Actividad 1. Introducción a Tkinter
# 08/10/2025
# Santillán Fuentes Jesús Emilio

# %%
import tkinter as tk
ventana = tk.Tk()
ventana.title("Mi primera ventana | Jesus Emilio")
ventana.geometry("300x200")
ventana.mainloop()
